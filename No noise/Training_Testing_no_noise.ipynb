# %%
import pandas as pd
import numpy as np
from IPython.display import display
from fastai.imports import *
from sklearn import metrics
from pandas.tseries.offsets import DateOffset
import matplotlib.pyplot as plt

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

Hour_ahead = 48

LRhourpreRMSE = []
LRhourpreMAE = []
for a in range(Hour_ahead):
    hour_ahead = a+1
    path = "/content/drive/MyDrive/Colab Notebooks/Project/No noise/no_noise.csv"
    Merge_all = pd.read_csv(path)
    dti = pd.to_datetime(Merge_all['DateTime'], format='%Y-%m-%d %H', exact=False)
    Merge_all.set_index(pd.Index(dti), inplace=True)
    Merge_all.drop(['DateTime'], axis=1, inplace=True)
    First = Merge_all.iloc[0:11000, :]
    N_index = First.shape
    Y_temp = First['FI']
    Y = Y_temp.iloc[hour_ahead:N_index[0]]
    Y = Y.to_numpy()

    X_temp1 = First['FI']
    X_temp2 = First.loc[:, First.columns != 'FI']
    X_temp2_index = X_temp2.index + DateOffset(hours=-hour_ahead)
    X_temp2.set_index(X_temp2_index, inplace=True)
    X_temp1 = X_temp1.to_frame()
    X_temp = X_temp1.join(X_temp2)
    X = X_temp.iloc[0:N_index[0] - hour_ahead]
    X = X.to_numpy()
    Pred_index = X.shape
    print("Shape = "+str(Pred_index))

    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=False)


    from sklearn.linear_model import LinearRegression

    reg = LinearRegression().fit(X_train,y_train)
    predf = reg.predict(X_test)

    MSE = mean_squared_error(y_test, predf, squared=True)
    print("Testing MSE  " + str(MSE))
    RMSE = np.sqrt(MSE)
    print("Testing RMSE  " + str(RMSE))
    MAE = mean_absolute_error(y_test, predf)
    print("Testing MAE  " + str(MAE))
    
    LRhourpreRMSE.append(RMSE)
    LRhourpreMAE.append(MAE)

print(LRhourpreRMSE)
print(LRhourpreMAE)
# Out:
# Shape = (10999, 780)
# Testing MSE  60.69441743324248
# Testing RMSE  7.790662194784374
# Testing MAE  5.518601534013256
# Shape = (10998, 780)
# Testing MSE  90.64207451158339
# Testing RMSE  9.520613137376362
# Testing MAE  7.238297385458576
# Shape = (10997, 780)
# Testing MSE  109.18907244628366
# Testing RMSE  10.449357513564346
# Testing MAE  8.20728059854371
# Shape = (10996, 780)
# Testing MSE  119.75718971566604
# Testing RMSE  10.943362815682665
# Testing MAE  8.710334039659829
# Shape = (10995, 780)
# Testing MSE  124.48933716849415
# Testing RMSE  11.157478979074716
# Testing MAE  8.988955018935423
# Shape = (10994, 780)
# Testing MSE  125.65281270736168
# Testing RMSE  11.209496541208336
# Testing MAE  9.062364971454677
# Shape = (10993, 780)
# Testing MSE  124.51515738101922
# Testing RMSE  11.158636000023444
# Testing MAE  9.021229052280827
# Shape = (10992, 780)
# Testing MSE  124.4640431334056
# Testing RMSE  11.156345420136722
# Testing MAE  9.020206364079439
# Shape = (10991, 780)
# Testing MSE  125.44846212843582
# Testing RMSE  11.200377767219988
# Testing MAE  9.065252940450428
# Shape = (10990, 780)
# Testing MSE  129.36236160657268
# Testing RMSE  11.373757585185851
# Testing MAE  9.225878688611667
# Shape = (10989, 780)
# Testing MSE  133.27738333831326
# Testing RMSE  11.544582423730763
# Testing MAE  9.403445577407012
# Shape = (10988, 780)
# Testing MSE  134.58946448059248
# Testing RMSE  11.601269951198985
# Testing MAE  9.47913233882402
# Shape = (10987, 780)
# Testing MSE  134.87792129210916
# Testing RMSE  11.613695419293084
# Testing MAE  9.506722375206587
# Shape = (10986, 780)
# Testing MSE  135.2243323655151
# Testing RMSE  11.628599759451482
# Testing MAE  9.5182367174002
# Shape = (10985, 780)
# Testing MSE  134.8404412873911
# Testing RMSE  11.61208169482936
# Testing MAE  9.502521330492774
# Shape = (10984, 780)
# Testing MSE  135.10928517052153
# Testing RMSE  11.623651972186776
# Testing MAE  9.498977059957934
# Shape = (10983, 780)
# Testing MSE  135.38181779224115
# Testing RMSE  11.635369258955263
# Testing MAE  9.504884854139018
# Shape = (10982, 780)
# Testing MSE  134.9007965561942
# Testing RMSE  11.614680217560627
# Testing MAE  9.482641144820946
# Shape = (10981, 780)
# Testing MSE  131.9611575696664
# Testing RMSE  11.487434768897119
# Testing MAE  9.353145468552604
# Shape = (10980, 780)
# Testing MSE  124.01425384938901
# Testing RMSE  11.136168723999695
# Testing MAE  8.993594779953025
# Shape = (10979, 780)
# Testing MSE  109.66894634967792
# Testing RMSE  10.472294225702308
# Testing MAE  8.388970289479838
# Shape = (10978, 780)
# Testing MSE  90.70594527485963
# Testing RMSE  9.523966887534817
# Testing MAE  7.5424421907352
# Shape = (10977, 780)
# Testing MSE  75.88440679162778
# Testing RMSE  8.71116563908802
# Testing MAE  6.7793175423554475
# Shape = (10976, 780)
# Testing MSE  80.25934176136542
# Testing RMSE  8.958757824685598
# Testing MAE  6.948011433348299
# Shape = (10975, 780)
# Testing MSE  97.17467117756618
# Testing RMSE  9.857721398861209
# Testing MAE  7.748494212171221
# Shape = (10974, 780)
# Testing MSE  113.45132773301107
# Testing RMSE  10.651353328709506
# Testing MAE  8.478160448424202
# Shape = (10973, 780)
# Testing MSE  123.73654979928097
# Testing RMSE  11.123693172650933
# Testing MAE  8.952637150052746
# Shape = (10972, 780)
# Testing MSE  129.50816216368767
# Testing RMSE  11.380165295973853
# Testing MAE  9.231328889973902
# Shape = (10971, 780)
# Testing MSE  132.3058766640247
# Testing RMSE  11.502429163616906
# Testing MAE  9.365650105929587
# Shape = (10970, 780)
# Testing MSE  133.43773052437876
# Testing RMSE  11.551525030245088
# Testing MAE  9.420229851652959
# Shape = (10969, 780)
# Testing MSE  132.50658580922186
# Testing RMSE  11.511150498938925
# Testing MAE  9.381468957900472
# Shape = (10968, 780)
# Testing MSE  131.67666022596416
# Testing RMSE  11.47504510779649
# Testing MAE  9.347566597524432
# Shape = (10967, 780)
# Testing MSE  131.75339688653895
# Testing RMSE  11.478388252996975
# Testing MAE  9.336818009091022
# Shape = (10966, 780)
# Testing MSE  133.0206536446394
# Testing RMSE  11.53345800896849
# Testing MAE  9.374802993967414
# Shape = (10965, 780)
# Testing MSE  134.45001063262842
# Testing RMSE  11.595258109789036
# Testing MAE  9.438426528246168
# Shape = (10964, 780)
# Testing MSE  135.16034860386975
# Testing RMSE  11.625848296097354
# Testing MAE  9.475984674822374
# Shape = (10963, 780)
# Testing MSE  135.05520333245767
# Testing RMSE  11.621325369012679
# Testing MAE  9.48519123792618
# Shape = (10962, 780)
# Testing MSE  134.97528948341116
# Testing RMSE  11.617886618632976
# Testing MAE  9.485984170528667
# Shape = (10961, 780)
# Testing MSE  135.16644854090003
# Testing RMSE  11.626110636876806
# Testing MAE  9.490437229619245
# Shape = (10960, 780)
# Testing MSE  135.77790318137556
# Testing RMSE  11.652377576330744
# Testing MAE  9.518268982602502
# Shape = (10959, 780)
# Testing MSE  136.5903749417267
# Testing RMSE  11.687188496029604
# Testing MAE  9.560356176654498
# Shape = (10958, 780)
# Testing MSE  137.03424167686393
# Testing RMSE  11.706162551274604
# Testing MAE  9.579738589990598
# Shape = (10957, 780)
# Testing MSE  135.41689864874132
# Testing RMSE  11.636876670685366
# Testing MAE  9.500965139925475
# Shape = (10956, 780)
# Testing MSE  130.19505031292084
# Testing RMSE  11.410304567053451
# Testing MAE  9.256080834388927
# Shape = (10955, 780)
# Testing MSE  120.80672503661174
# Testing RMSE  10.991211263396393
# Testing MAE  8.818232931916365
# Shape = (10954, 780)
# Testing MSE  108.5255430793434
# Testing RMSE  10.417559362890302
# Testing MAE  8.246543542892754
# Shape = (10953, 780)
# Testing MSE  98.42804144171765
# Testing RMSE  9.921090738508425
# Testing MAE  7.749174967313133
# Shape = (10952, 780)
# Testing MSE  100.00988414393797
# Testing RMSE  10.000494194985464
# Testing MAE  7.790680763136857
# [7.790662194784374, 9.520613137376362, 10.449357513564346, 10.943362815682665, 11.157478979074716, 11.209496541208336, 11.158636000023444, 11.156345420136722, 11.200377767219988, 11.373757585185851, 11.544582423730763, 11.601269951198985, 11.613695419293084, 11.628599759451482, 11.61208169482936, 11.623651972186776, 11.635369258955263, 11.614680217560627, 11.487434768897119, 11.136168723999695, 10.472294225702308, 9.523966887534817, 8.71116563908802, 8.958757824685598, 9.857721398861209, 10.651353328709506, 11.123693172650933, 11.380165295973853, 11.502429163616906, 11.551525030245088, 11.511150498938925, 11.47504510779649, 11.478388252996975, 11.53345800896849, 11.595258109789036, 11.625848296097354, 11.621325369012679, 11.617886618632976, 11.626110636876806, 11.652377576330744, 11.687188496029604, 11.706162551274604, 11.636876670685366, 11.410304567053451, 10.991211263396393, 10.417559362890302, 9.921090738508425, 10.000494194985464]
# [5.518601534013256, 7.238297385458576, 8.20728059854371, 8.710334039659829, 8.988955018935423, 9.062364971454677, 9.021229052280827, 9.020206364079439, 9.065252940450428, 9.225878688611667, 9.403445577407012, 9.47913233882402, 9.506722375206587, 9.5182367174002, 9.502521330492774, 9.498977059957934, 9.504884854139018, 9.482641144820946, 9.353145468552604, 8.993594779953025, 8.388970289479838, 7.5424421907352, 6.7793175423554475, 6.948011433348299, 7.748494212171221, 8.478160448424202, 8.952637150052746, 9.231328889973902, 9.365650105929587, 9.420229851652959, 9.381468957900472, 9.347566597524432, 9.336818009091022, 9.374802993967414, 9.438426528246168, 9.475984674822374, 9.48519123792618, 9.485984170528667, 9.490437229619245, 9.518268982602502, 9.560356176654498, 9.579738589990598, 9.500965139925475, 9.256080834388927, 8.818232931916365, 8.246543542892754, 7.749174967313133, 7.790680763136857]

# %%
import pandas as pd
import numpy as np
from IPython.display import display
from fastai.imports import *
from sklearn import metrics
from pandas.tseries.offsets import DateOffset
import matplotlib.pyplot as plt

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

Hour_ahead = 48

LRhourpreRMSE2 = []
LRhourpreMAE2 = []
for a in range(Hour_ahead):
    hour_ahead = a+1
    path = "/content/drive/MyDrive/Colab Notebooks/Project/No noise/NoiseMu0Sigma1.csv"
    Merge_all = pd.read_csv(path)
    dti = pd.to_datetime(Merge_all['DateTime'], format='%Y-%m-%d %H', exact=False)
    Merge_all.set_index(pd.Index(dti), inplace=True)
    Merge_all.drop(['DateTime'], axis=1, inplace=True)
    First = Merge_all.iloc[0:11000, :]
    N_index = First.shape
    Y_temp = First['FI']
    Y = Y_temp.iloc[hour_ahead:N_index[0]]
    Y = Y.to_numpy()

    X_temp1 = First['FI']
    X_temp2 = First.loc[:, First.columns != 'FI']
    X_temp2_index = X_temp2.index + DateOffset(hours=-hour_ahead)
    X_temp2.set_index(X_temp2_index, inplace=True)
    X_temp1 = X_temp1.to_frame()
    X_temp = X_temp1.join(X_temp2)
    X = X_temp.iloc[0:N_index[0] - hour_ahead]
    X = X.to_numpy()
    Pred_index = X.shape
    print("Shape = "+str(Pred_index))

    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=False)


    from sklearn.linear_model import LinearRegression

    reg = LinearRegression().fit(X_train,y_train)
    predf = reg.predict(X_test)

    MSE = mean_squared_error(y_test, predf, squared=True)
    print("Testing MSE  " + str(MSE))
    RMSE = np.sqrt(MSE)
    print("Testing RMSE  " + str(RMSE))
    MAE = mean_absolute_error(y_test, predf)
    print("Testing MAE  " + str(MAE))
    
    LRhourpreRMSE2.append(RMSE)
    LRhourpreMAE2.append(MAE)

print(LRhourpreRMSE2)
print(LRhourpreMAE2)
# Out:
# Shape = (10999, 780)
# Testing MSE  60.560870636846914
# Testing RMSE  7.782086522061221
# Testing MAE  5.492301006250015
# Shape = (10998, 780)
# Testing MSE  88.59877795629868
# Testing RMSE  9.412692386150663
# Testing MAE  7.088643003096404
# Shape = (10997, 780)
# Testing MSE  106.22049611863815
# Testing RMSE  10.306332816217326
# Testing MAE  8.069553584829219
# Shape = (10996, 780)
# Testing MSE  115.31176810309663
# Testing RMSE  10.738331718805144
# Testing MAE  8.559819185783253
# Shape = (10995, 780)
# Testing MSE  119.4022352332676
# Testing RMSE  10.927132983233415
# Testing MAE  8.794712739656436
# Shape = (10994, 780)
# Testing MSE  119.94588271273363
# Testing RMSE  10.951980766634573
# Testing MAE  8.829899007558096
# Shape = (10993, 780)
# Testing MSE  119.67456574518948
# Testing RMSE  10.939587092079366
# Testing MAE  8.802768589377603
# Shape = (10992, 780)
# Testing MSE  119.91626277376231
# Testing RMSE  10.95062841912565
# Testing MAE  8.799509080699696
# Shape = (10991, 780)
# Testing MSE  121.68041747590952
# Testing RMSE  11.03088470957382
# Testing MAE  8.894868246744332
# Shape = (10990, 780)
# Testing MSE  125.60115211038628
# Testing RMSE  11.207191981508405
# Testing MAE  9.058053254052293
# Shape = (10989, 780)
# Testing MSE  129.34382297882516
# Testing RMSE  11.372942582235487
# Testing MAE  9.261760869721531
# Shape = (10988, 780)
# Testing MSE  129.84364968518784
# Testing RMSE  11.394895773335877
# Testing MAE  9.30725796443389
# Shape = (10987, 780)
# Testing MSE  129.5286170375673
# Testing RMSE  11.381063967730228
# Testing MAE  9.313572713388144
# Shape = (10986, 780)
# Testing MSE  129.24743558590475
# Testing RMSE  11.36870421753969
# Testing MAE  9.311466528171337
# Shape = (10985, 780)
# Testing MSE  128.84734941471453
# Testing RMSE  11.351094635087602
# Testing MAE  9.29423133313326
# Shape = (10984, 780)
# Testing MSE  128.90137884339333
# Testing RMSE  11.35347430716225
# Testing MAE  9.283692719032533
# Shape = (10983, 780)
# Testing MSE  129.082237898302
# Testing RMSE  11.361436436397556
# Testing MAE  9.281175673010774
# Shape = (10982, 780)
# Testing MSE  128.30265487700845
# Testing RMSE  11.327076183950052
# Testing MAE  9.244078982208446
# Shape = (10981, 780)
# Testing MSE  124.86639924058376
# Testing RMSE  11.174363482569545
# Testing MAE  9.097152974000615
# Shape = (10980, 780)
# Testing MSE  116.86762856306896
# Testing RMSE  10.81053322288355
# Testing MAE  8.74322683199323
# Shape = (10979, 780)
# Testing MSE  103.12496787687391
# Testing RMSE  10.155046424161434
# Testing MAE  8.150337796231167
# Shape = (10978, 780)
# Testing MSE  85.13619947279794
# Testing RMSE  9.226927954243381
# Testing MAE  7.330178269790869
# Shape = (10977, 780)
# Testing MSE  71.89511135912376
# Testing RMSE  8.479098499199296
# Testing MAE  6.607456060317144
# Shape = (10976, 780)
# Testing MSE  76.75524003213633
# Testing RMSE  8.761006793293584
# Testing MAE  6.844555257331579
# Shape = (10975, 780)
# Testing MSE  93.11339701305538
# Testing RMSE  9.649528331118335
# Testing MAE  7.6810469411498365
# Shape = (10974, 780)
# Testing MSE  108.60768101485273
# Testing RMSE  10.421500900295156
# Testing MAE  8.413161673241069
# Shape = (10973, 780)
# Testing MSE  117.89686422140876
# Testing RMSE  10.858032244445067
# Testing MAE  8.803986887258398
# Shape = (10972, 780)
# Testing MSE  123.39170374099864
# Testing RMSE  11.10818183777159
# Testing MAE  9.035957078895883
# Shape = (10971, 780)
# Testing MSE  125.65835192769944
# Testing RMSE  11.209743615609566
# Testing MAE  9.13354249157187
# Shape = (10970, 780)
# Testing MSE  126.89160617738848
# Testing RMSE  11.264617444786506
# Testing MAE  9.180969646618381
# Shape = (10969, 780)
# Testing MSE  126.46334938832615
# Testing RMSE  11.245592442745119
# Testing MAE  9.158941416728121
# Testing MSE  125.8277292598721
# Testing RMSE  11.2172959869958
# Testing MAE  9.124246751716253
# Shape = (10967, 780)
# Testing MSE  126.25695372970797
# Testing RMSE  11.236411959772033
# Testing MAE  9.134371905939885
# Shape = (10966, 780)
# Testing MSE  127.47768783110037
# Testing RMSE  11.290601747962787
# Testing MAE  9.189763654665466
# Shape = (10965, 780)
# Testing MSE  128.80712488785852
# Testing RMSE  11.34932266207365
# Testing MAE  9.253083019267663
# Shape = (10964, 780)
# Testing MSE  129.61748990127808
# Testing RMSE  11.384967716303725
# Testing MAE  9.298589633654727
# Shape = (10963, 780)
# Testing MSE  129.3188209140869
# Testing RMSE  11.371843338442844
# Testing MAE  9.295856324749831
# Shape = (10962, 780)
# Testing MSE  129.2009680895696
# Testing RMSE  11.366660375394773
# Testing MAE  9.29468805485531
# Shape = (10961, 780)
# Testing MSE  129.4566811456002
# Testing RMSE  11.377903196353895
# Testing MAE  9.303158638001921
# Shape = (10960, 780)
# Testing MSE  130.0283115924939
# Testing RMSE  11.402995728864143
# Testing MAE  9.31795558931378
# Shape = (10959, 780)
# Testing MSE  130.4932557622901
# Testing RMSE  11.423364467716597
# Testing MAE  9.33942605723872
# Shape = (10958, 780)
# Testing MSE  130.2509002327513
# Testing RMSE  11.41275165035809
# Testing MAE  9.328429030372275
# Shape = (10957, 780)
# Testing MSE  127.992403119983
# Testing RMSE  11.313372756167057
# Testing MAE  9.22579770441339
# Shape = (10956, 780)
# Testing MSE  122.29568963539762
# Testing RMSE  11.058738157466141
# Testing MAE  8.968275088093625
# Shape = (10955, 780)
# Testing MSE  112.6206358892741
# Testing RMSE  10.612287024448316
# Testing MAE  8.536267268344686
# Shape = (10954, 780)
# Testing MSE  100.01453635286073
# Testing RMSE  10.000726791231761
# Testing MAE  7.944963130402477
# Shape = (10953, 780)
# Testing MSE  90.48050478439959
# Testing RMSE  9.51212409424938
# Testing MAE  7.481787410868707
# Shape = (10952, 780)
# Testing MSE  93.28329450585778
# Testing RMSE  9.658327728227997
# Testing MAE  7.594232599844784
# [7.782086522061221, 9.412692386150663, 10.306332816217326, 10.738331718805144, 10.927132983233415, 10.951980766634573, 10.939587092079366, 10.95062841912565, 11.03088470957382, 11.207191981508405, 11.372942582235487, 11.394895773335877, 11.381063967730228, 11.36870421753969, 11.351094635087602, 11.35347430716225, 11.361436436397556, 11.327076183950052, 11.174363482569545, 10.81053322288355, 10.155046424161434, 9.226927954243381, 8.479098499199296, 8.761006793293584, 9.649528331118335, 10.421500900295156, 10.858032244445067, 11.10818183777159, 11.209743615609566, 11.264617444786506, 11.245592442745119, 11.2172959869958, 11.236411959772033, 11.290601747962787, 11.34932266207365, 11.384967716303725, 11.371843338442844, 11.366660375394773, 11.377903196353895, 11.402995728864143, 11.423364467716597, 11.41275165035809, 11.313372756167057, 11.058738157466141, 10.612287024448316, 10.000726791231761, 9.51212409424938, 9.658327728227997]
# [5.492301006250015, 7.088643003096404, 8.069553584829219, 8.559819185783253, 8.794712739656436, 8.829899007558096, 8.802768589377603, 8.799509080699696, 8.894868246744332, 9.058053254052293, 9.261760869721531, 9.30725796443389, 9.313572713388144, 9.311466528171337, 9.29423133313326, 9.283692719032533, 9.281175673010774, 9.244078982208446, 9.097152974000615, 8.74322683199323, 8.150337796231167, 7.330178269790869, 6.607456060317144, 6.844555257331579, 7.6810469411498365, 8.413161673241069, 8.803986887258398, 9.035957078895883, 9.13354249157187, 9.180969646618381, 9.158941416728121, 9.124246751716253, 9.134371905939885, 9.189763654665466, 9.253083019267663, 9.298589633654727, 9.295856324749831, 9.29468805485531, 9.303158638001921, 9.31795558931378, 9.33942605723872, 9.328429030372275, 9.22579770441339, 8.968275088093625, 8.536267268344686, 7.944963130402477, 7.481787410868707, 7.594232599844784]

# %%
import pandas as pd
import numpy as np
from IPython.display import display
from fastai.imports import *
from sklearn import metrics
from pandas.tseries.offsets import DateOffset
import matplotlib.pyplot as plt

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

Hour_ahead = 48

LRhourpreRMSE3 = []
LRhourpreMAE3 = []
for a in range(Hour_ahead):
    hour_ahead = a+1
    path = "/content/drive/MyDrive/Colab Notebooks/Project/No noise/NoiseMu0Sigma0.5.csv"
    Merge_all = pd.read_csv(path)
    dti = pd.to_datetime(Merge_all['DateTime'], format='%Y-%m-%d %H', exact=False)
    Merge_all.set_index(pd.Index(dti), inplace=True)
    Merge_all.drop(['DateTime'], axis=1, inplace=True)
    First = Merge_all.iloc[0:11000, :]
    N_index = First.shape
    Y_temp = First['FI']
    Y = Y_temp.iloc[hour_ahead:N_index[0]]
    Y = Y.to_numpy()

    X_temp1 = First['FI']
    X_temp2 = First.loc[:, First.columns != 'FI']
    X_temp2_index = X_temp2.index + DateOffset(hours=-hour_ahead)
    X_temp2.set_index(X_temp2_index, inplace=True)
    X_temp1 = X_temp1.to_frame()
    X_temp = X_temp1.join(X_temp2)
    X = X_temp.iloc[0:N_index[0] - hour_ahead]
    X = X.to_numpy()
    Pred_index = X.shape
    print("Shape = "+str(Pred_index))

    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=False)


    from sklearn.linear_model import LinearRegression

    reg = LinearRegression().fit(X_train,y_train)
    predf = reg.predict(X_test)

    MSE = mean_squared_error(y_test, predf, squared=True)
    print("Testing MSE  " + str(MSE))
    RMSE = np.sqrt(MSE)
    print("Testing RMSE  " + str(RMSE))
    MAE = mean_absolute_error(y_test, predf)
    print("Testing MAE  " + str(MAE))
    
    LRhourpreRMSE3.append(RMSE)
    LRhourpreMAE3.append(MAE)

print(LRhourpreRMSE3)
print(LRhourpreMAE3)
# Out:
# Shape = (10999, 780)
# Testing MSE  61.14377417255439
# Testing RMSE  7.819448457055931
# Testing MAE  5.457606881869031
# Shape = (10998, 780)
# Testing MSE  89.55476998293386
# Testing RMSE  9.463338205038108
# Testing MAE  7.049129865827211
# Shape = (10997, 780)
# Testing MSE  108.05939237516831
# Testing RMSE  10.395161969645702
# Testing MAE  8.075237360480628
# Shape = (10996, 780)
# Testing MSE  118.89337041933565
# Testing RMSE  10.90382366050257
# Testing MAE  8.586961353846242
# Shape = (10995, 780)
# Testing MSE  123.97657706994966
# Testing RMSE  11.134476955382757
# Testing MAE  8.885189318478176
# Shape = (10994, 780)
# Testing MSE  125.08618053912357
# Testing RMSE  11.1841933343055
# Testing MAE  8.978384454352723
# Shape = (10993, 780)
# Testing MSE  124.32913084857216
# Testing RMSE  11.150297343504889
# Testing MAE  8.947555215973573
# Shape = (10992, 780)
# Testing MSE  125.01852842697333
# Testing RMSE  11.181168473239875
# Testing MAE  8.969245817327087
# Shape = (10991, 780)
# Testing MSE  126.35453712116211
# Testing RMSE  11.240753405406691
# Testing MAE  9.034772062772788
# Shape = (10990, 780)
# Testing MSE  130.13111119957028
# Testing RMSE  11.407502408484088
# Testing MAE  9.20735437881196
# Shape = (10989, 780)
# Testing MSE  133.6937593320117
# Testing RMSE  11.562601754450064
# Testing MAE  9.387393931381428
# Shape = (10988, 780)
# Testing MSE  135.03121432243043
# Testing RMSE  11.620293211551523
# Testing MAE  9.45496888295093
# Shape = (10987, 780)
# Testing MSE  135.1720266454518
# Testing RMSE  11.626350529957877
# Testing MAE  9.47398551495965
# Shape = (10986, 780)
# Testing MSE  135.0902356006603
# Testing RMSE  11.622832511942185
# Testing MAE  9.466973049511592
# Shape = (10985, 780)
# Testing MSE  134.64748418427234
# Testing RMSE  11.603770257303113
# Testing MAE  9.432196588004794
# Shape = (10984, 780)
# Testing MSE  135.0477899434189
# Testing RMSE  11.62100640837182
# Testing MAE  9.43188143751193
# Shape = (10983, 780)
# Testing MSE  135.28538893224703
# Testing RMSE  11.631224739134183
# Testing MAE  9.435781718689825
# Shape = (10982, 780)
# Testing MSE  134.3419070928797
# Testing RMSE  11.590595631497102
# Testing MAE  9.391861733253787
# Shape = (10981, 780)
# Testing MSE  130.63789505023902
# Testing RMSE  11.429693567643842
# Testing MAE  9.230735511353178
# Shape = (10980, 780)
# Testing MSE  121.80625341903566
# Testing RMSE  11.036587036717268
# Testing MAE  8.846506632004527
# Shape = (10979, 780)
# Testing MSE  107.1245772593178
# Testing RMSE  10.3501003502052
# Testing MAE  8.22763480517547
# Shape = (10978, 780)
# Testing MSE  88.03808513181578
# Testing RMSE  9.382861244408113
# Testing MAE  7.3801918624796805
# Shape = (10977, 780)
# Testing MSE  73.9169575972489
# Testing RMSE  8.597497170528694
# Testing MAE  6.651605796285828
# Shape = (10976, 780)
# Testing MSE  78.36550406769285
# Testing RMSE  8.852429274933115
# Testing MAE  6.830605791257145
# Shape = (10975, 780)
# Testing MSE  95.42049739330822
# Testing RMSE  9.768341588688852
# Testing MAE  7.616789118188592
# Shape = (10974, 780)
# Testing MSE  111.42742436455765
# Testing RMSE  10.55591892563398
# Testing MAE  8.33797441075981
# Shape = (10973, 780)
# Testing MSE  121.8425923298191
# Testing RMSE  11.038233206895889
# Testing MAE  8.805305720515618
# Shape = (10972, 780)
# Testing MSE  128.38010990077572
# Testing RMSE  11.330494689146441
# Testing MAE  9.106574887157034
# Shape = (10971, 780)
# Testing MSE  131.95650227793683
# Testing RMSE  11.487232141727477
# Testing MAE  9.278215018837175
# Shape = (10970, 780)
# Testing MSE  133.11670117030795
# Testing RMSE  11.53762112267117
# Testing MAE  9.340698559921279
# Shape = (10969, 780)
# Testing MSE  132.69018151016064
# Testing RMSE  11.519122427952603
# Testing MAE  9.318391661830512
# Shape = (10968, 780)
# Testing MSE  132.042959433406
# Testing RMSE  11.490994710354974
# Testing MAE  9.29402467579993
# Shape = (10967, 780)
# Testing MSE  132.45574398365648
# Testing RMSE  11.508941914166414
# Testing MAE  9.301788251557891
# Shape = (10966, 780)
# Testing MSE  133.90771755875977
# Testing RMSE  11.571850221929067
# Testing MAE  9.358769120798238
# Shape = (10965, 780)
# Testing MSE  135.23418748010107
# Testing RMSE  11.629023496411945
# Testing MAE  9.425296455516
# Shape = (10964, 780)
# Testing MSE  135.8132072749183
# Testing RMSE  11.65389236585435
# Testing MAE  9.454123927357953
# Shape = (10963, 780)
# Testing MSE  135.53871108795073
# Testing RMSE  11.642109391684599
# Testing MAE  9.45910703456166
# Shape = (10962, 780)
# Testing MSE  135.48727149093827
# Testing RMSE  11.639899977703342
# Testing MAE  9.46098979491195
# Shape = (10961, 780)
# Testing MSE  135.7471927528044
# Testing RMSE  11.651059726600169
# Testing MAE  9.456459074919678
# Shape = (10960, 780)
# Testing MSE  136.262759467823
# Testing RMSE  11.673164072684964
# Testing MAE  9.47783802026227
# Shape = (10959, 780)
# Testing MSE  136.9140153157296
# Testing RMSE  11.701026250535874
# Testing MAE  9.511827044367058
# Shape = (10958, 780)
# Testing MSE  136.97187778007913
# Testing RMSE  11.703498527366897
# Testing MAE  9.512841102153155
# Shape = (10957, 780)
# Testing MSE  134.85947679896196
# Testing RMSE  11.61290130841393
# Testing MAE  9.415808820871813
# Shape = (10956, 780)
# Testing MSE  129.08134370915042
# Testing RMSE  11.361397084388452
# Testing MAE  9.165019790186443
# Shape = (10955, 780)
# Testing MSE  119.42584649045439
# Testing RMSE  10.928213325628962
# Testing MAE  8.730491784378092
# Shape = (10954, 780)
# Testing MSE  107.2938422326717
# Testing RMSE  10.358274095266628
# Testing MAE  8.17410438506281
# Shape = (10953, 780)
# Testing MSE  97.07028499730973
# Testing RMSE  9.852425335789647
# Testing MAE  7.702557493101545
# Shape = (10952, 780)
# Testing MSE  98.80937614535884
# Testing RMSE  9.940290546325034
# Testing MAE  7.711900156655928
# [7.819448457055931, 9.463338205038108, 10.395161969645702, 10.90382366050257, 11.134476955382757, 11.1841933343055, 11.150297343504889, 11.181168473239875, 11.240753405406691, 11.407502408484088, 11.562601754450064, 11.620293211551523, 11.626350529957877, 11.622832511942185, 11.603770257303113, 11.62100640837182, 11.631224739134183, 11.590595631497102, 11.429693567643842, 11.036587036717268, 10.3501003502052, 9.382861244408113, 8.597497170528694, 8.852429274933115, 9.768341588688852, 10.55591892563398, 11.038233206895889, 11.330494689146441, 11.487232141727477, 11.53762112267117, 11.519122427952603, 11.490994710354974, 11.508941914166414, 11.571850221929067, 11.629023496411945, 11.65389236585435, 11.642109391684599, 11.639899977703342, 11.651059726600169, 11.673164072684964, 11.701026250535874, 11.703498527366897, 11.61290130841393, 11.361397084388452, 10.928213325628962, 10.358274095266628, 9.852425335789647, 9.940290546325034]
# [5.457606881869031, 7.049129865827211, 8.075237360480628, 8.586961353846242, 8.885189318478176, 8.978384454352723, 8.947555215973573, 8.969245817327087, 9.034772062772788, 9.20735437881196, 9.387393931381428, 9.45496888295093, 9.47398551495965, 9.466973049511592, 9.432196588004794, 9.43188143751193, 9.435781718689825, 9.391861733253787, 9.230735511353178, 8.846506632004527, 8.22763480517547, 7.3801918624796805, 6.651605796285828, 6.830605791257145, 7.616789118188592, 8.33797441075981, 8.805305720515618, 9.106574887157034, 9.278215018837175, 9.340698559921279, 9.318391661830512, 9.29402467579993, 9.301788251557891, 9.358769120798238, 9.425296455516, 9.454123927357953, 9.45910703456166, 9.46098979491195, 9.456459074919678, 9.47783802026227, 9.511827044367058, 9.512841102153155, 9.415808820871813, 9.165019790186443, 8.730491784378092, 8.17410438506281, 7.702557493101545, 7.711900156655928]

# %%
import pandas as pd
import numpy as np
from IPython.display import display
from fastai.imports import *
from sklearn import metrics
from pandas.tseries.offsets import DateOffset
import matplotlib.pyplot as plt

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

Hour_ahead = 48

LRhourpreRMSE4 = []
LRhourpreMAE4 = []
for a in range(Hour_ahead):
    hour_ahead = a+1
    path = "/content/drive/MyDrive/Colab Notebooks/Project/No noise/NoiseMu0Sigma2.csv"
    Merge_all = pd.read_csv(path)
    dti = pd.to_datetime(Merge_all['DateTime'], format='%Y-%m-%d %H', exact=False)
    Merge_all.set_index(pd.Index(dti), inplace=True)
    Merge_all.drop(['DateTime'], axis=1, inplace=True)
    First = Merge_all.iloc[0:11000, :]
    N_index = First.shape
    Y_temp = First['FI']
    Y = Y_temp.iloc[hour_ahead:N_index[0]]
    Y = Y.to_numpy()

    X_temp1 = First['FI']
    X_temp2 = First.loc[:, First.columns != 'FI']
    X_temp2_index = X_temp2.index + DateOffset(hours=-hour_ahead)
    X_temp2.set_index(X_temp2_index, inplace=True)
    X_temp1 = X_temp1.to_frame()
    X_temp = X_temp1.join(X_temp2)
    X = X_temp.iloc[0:N_index[0] - hour_ahead]
    X = X.to_numpy()
    Pred_index = X.shape
    print("Shape = "+str(Pred_index))

    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=False)


    from sklearn.linear_model import LinearRegression

    reg = LinearRegression().fit(X_train,y_train)
    predf = reg.predict(X_test)

    MSE = mean_squared_error(y_test, predf, squared=True)
    print("Testing MSE  " + str(MSE))
    RMSE = np.sqrt(MSE)
    print("Testing RMSE  " + str(RMSE))
    MAE = mean_absolute_error(y_test, predf)
    print("Testing MAE  " + str(MAE))
    
    LRhourpreRMSE4.append(RMSE)
    LRhourpreMAE4.append(MAE)

print(LRhourpreRMSE4)
print(LRhourpreMAE4)
# Out:
# Shape = (10999, 780)
# Testing MSE  61.01178212160943
# Testing RMSE  7.81100391253323
# Testing MAE  5.477384274863846
# Shape = (10998, 780)
# Testing MSE  89.10259561957125
# Testing RMSE  9.439417122872113
# Testing MAE  7.180395091027761
# Shape = (10997, 780)
# Testing MSE  107.5879420233789
# Testing RMSE  10.372460750630918
# Testing MAE  8.229304988060559
# Shape = (10996, 780)
# Testing MSE  117.52275554267449
# Testing RMSE  10.840791278438788
# Testing MAE  8.743798130605947
# Shape = (10995, 780)
# Testing MSE  121.81899868567953
# Testing RMSE  11.037164431396297
# Testing MAE  9.001772902685618
# Shape = (10994, 780)
# Testing MSE  123.04503778275618
# Testing RMSE  11.0925667806309
# Testing MAE  9.047560477001937
# Shape = (10993, 780)
# Testing MSE  123.11809638054658
# Testing RMSE  11.09585942505341
# Testing MAE  9.041596911349574
# Shape = (10992, 780)
# Testing MSE  124.12070520080725
# Testing RMSE  11.140947230860007
# Testing MAE  9.080468679851295
# Shape = (10991, 780)
# Testing MSE  125.99340181666057
# Testing RMSE  11.224678250028397
# Testing MAE  9.156872855492272
# Shape = (10990, 780)
# Testing MSE  129.84693905524745
# Testing RMSE  11.39504010766296
# Testing MAE  9.314406682080715
# Shape = (10989, 780)
# Testing MSE  132.9359548059139
# Testing RMSE  11.529785548999335
# Testing MAE  9.47911444693116
# Shape = (10988, 780)
# Testing MSE  134.091712759613
# Testing RMSE  11.579797613067898
# Testing MAE  9.555637806913786
# Shape = (10987, 780)
# Testing MSE  133.91165799733938
# Testing RMSE  11.572020480337017
# Testing MAE  9.561245104421687
# Shape = (10986, 780)
# Testing MSE  132.9437717550265
# Testing RMSE  11.530124533370248
# Testing MAE  9.53705119449644
# Shape = (10985, 780)
# Testing MSE  133.18271715652463
# Testing RMSE  11.540481669173285
# Testing MAE  9.552802727864838
# Shape = (10984, 780)
# Testing MSE  134.17281572854904
# Testing RMSE  11.583299000222219
# Testing MAE  9.592507853017702
# Shape = (10983, 780)
# Testing MSE  134.45233134809766
# Testing RMSE  11.595358181104094
# Testing MAE  9.597549447628932
# Shape = (10982, 780)
# Testing MSE  133.05025677945034
# Testing RMSE  11.534741296598305
# Testing MAE  9.541126731189609
# Shape = (10981, 780)
# Testing MSE  128.54845355017477
# Testing RMSE  11.337921041803686
# Testing MAE  9.342021208529177
# Shape = (10980, 780)
# Testing MSE  118.83363386707484
# Testing RMSE  10.901084068434425
# Testing MAE  8.916905883932198
# Shape = (10979, 780)
# Testing MSE  103.50531545944148
# Testing RMSE  10.173756211913153
# Testing MAE  8.24897032199349
# Shape = (10978, 780)
# Testing MSE  84.05173822585039
# Testing RMSE  9.16797350704344
# Testing MAE  7.32013014188456
# Shape = (10977, 780)
# Testing MSE  70.45956292239373
# Testing RMSE  8.394019473553401
# Testing MAE  6.535094227308555
# Shape = (10976, 780)
# Testing MSE  75.86793517611963
# Testing RMSE  8.710220156581556
# Testing MAE  6.7842313752762555
# Shape = (10975, 780)
# Testing MSE  92.27830505180766
# Testing RMSE  9.606159745278426
# Testing MAE  7.633398068480853
# Shape = (10974, 780)
# Testing MSE  108.79305896168086
# Testing RMSE  10.430391122181414
# Testing MAE  8.434967047665689
# Shape = (10973, 780)
# Testing MSE  119.56912479215264
# Testing RMSE  10.934766791850324
# Testing MAE  8.966392546921416
# Shape = (10972, 780)
# Testing MSE  125.64183724758172
# Testing RMSE  11.20900696973562
# Testing MAE  9.239512058806108
# Shape = (10971, 780)
# Testing MSE  129.16598157712468
# Testing RMSE  11.365121274193456
# Testing MAE  9.37236030808676
# Shape = (10970, 780)
# Testing MSE  130.9136707901508
# Testing RMSE  11.441751211687432
# Testing MAE  9.431660653193147
# Shape = (10969, 780)
# Testing MSE  130.8639873796781
# Testing RMSE  11.439579860278004
# Testing MAE  9.421305439199715
# Shape = (10968, 780)
# Testing MSE  130.29289633688487
# Testing RMSE  11.41459137844561
# Testing MAE  9.381308286619268
# Shape = (10967, 780)
# Testing MSE  130.57316564868287
# Testing RMSE  11.426861583509396
# Testing MAE  9.381064735448533
# Shape = (10966, 780)
# Testing MSE  131.7792099259331
# Testing RMSE  11.479512617090199
# Testing MAE  9.427965033772345
# Shape = (10965, 780)
# Testing MSE  132.82849953048256
# Testing RMSE  11.525124707806096
# Testing MAE  9.48237795325209
# Shape = (10964, 780)
# Testing MSE  133.53824655037968
# Testing RMSE  11.555874979869749
# Testing MAE  9.51842151934459
# Shape = (10963, 780)
# Testing MSE  133.70486657711115
# Testing RMSE  11.56308205354918
# Testing MAE  9.554561837966325
# Shape = (10962, 780)
# Testing MSE  134.03310519833988
# Testing RMSE  11.577266741262372
# Testing MAE  9.5716632947532
# Shape = (10961, 780)
# Testing MSE  135.0741314187122
# Testing RMSE  11.622139709137565
# Testing MAE  9.609625710331189
# Shape = (10960, 780)
# Testing MSE  136.07989268166378
# Testing RMSE  11.665328657250244
# Testing MAE  9.640422271899984
# Shape = (10959, 780)
# Testing MSE  136.73424082727868
# Testing RMSE  11.69334173054387
# Testing MAE  9.665920021842421
# Shape = (10958, 780)
# Testing MSE  136.29121457086734
# Testing RMSE  11.674382834688407
# Testing MAE  9.648303007011313
# Shape = (10957, 780)
# Testing MSE  133.18506041871652
# Testing RMSE  11.540583192313832
# Testing MAE  9.526203329474344
# Shape = (10956, 780)
# Testing MSE  126.3841025331184
# Testing RMSE  11.2420684277013
# Testing MAE  9.238135369381483
# Shape = (10955, 780)
# Testing MSE  115.99663082782779
# Testing RMSE  10.770173203241802
# Testing MAE  8.806136535689587
# Shape = (10954, 780)
# Testing MSE  102.46934006937937
# Testing RMSE  10.122714066364779
# Testing MAE  8.199260439436253
# Shape = (10953, 780)
# Testing MSE  92.2667224268223
# Testing RMSE  9.605556851470002
# Testing MAE  7.681214892259635
# Shape = (10952, 780)
# Testing MSE  93.80315152573297
# Testing RMSE  9.685202709583985
# Testing MAE  7.754337629629929
# [7.81100391253323, 9.439417122872113, 10.372460750630918, 10.840791278438788, 11.037164431396297, 11.0925667806309, 11.09585942505341, 11.140947230860007, 11.224678250028397, 11.39504010766296, 11.529785548999335, 11.579797613067898, 11.572020480337017, 11.530124533370248, 11.540481669173285, 11.583299000222219, 11.595358181104094, 11.534741296598305, 11.337921041803686, 10.901084068434425, 10.173756211913153, 9.16797350704344, 8.394019473553401, 8.710220156581556, 9.606159745278426, 10.430391122181414, 10.934766791850324, 11.20900696973562, 11.365121274193456, 11.441751211687432, 11.439579860278004, 11.41459137844561, 11.426861583509396, 11.479512617090199, 11.525124707806096, 11.555874979869749, 11.56308205354918, 11.577266741262372, 11.622139709137565, 11.665328657250244, 11.69334173054387, 11.674382834688407, 11.540583192313832, 11.2420684277013, 10.770173203241802, 10.122714066364779, 9.605556851470002, 9.685202709583985]
# [5.477384274863846, 7.180395091027761, 8.229304988060559, 8.743798130605947, 9.001772902685618, 9.047560477001937, 9.041596911349574, 9.080468679851295, 9.156872855492272, 9.314406682080715, 9.47911444693116, 9.555637806913786, 9.561245104421687, 9.53705119449644, 9.552802727864838, 9.592507853017702, 9.597549447628932, 9.541126731189609, 9.342021208529177, 8.916905883932198, 8.24897032199349, 7.32013014188456, 6.535094227308555, 6.7842313752762555, 7.633398068480853, 8.434967047665689, 8.966392546921416, 9.239512058806108, 9.37236030808676, 9.431660653193147, 9.421305439199715, 9.381308286619268, 9.381064735448533, 9.427965033772345, 9.48237795325209, 9.51842151934459, 9.554561837966325, 9.5716632947532, 9.609625710331189, 9.640422271899984, 9.665920021842421, 9.648303007011313, 9.526203329474344, 9.238135369381483, 8.806136535689587, 8.199260439436253, 7.681214892259635, 7.754337629629929]

# %%
import pandas as pd
import numpy as np
from IPython.display import display
from fastai.imports import *
from sklearn import metrics
from pandas.tseries.offsets import DateOffset
import matplotlib.pyplot as plt

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

Hour_ahead = 48

LRhourpreRMSE5 = []
LRhourpreMAE5 = []
for a in range(Hour_ahead):
    hour_ahead = a+1
    path = "/content/drive/MyDrive/Colab Notebooks/Project/No noise/NoiseMu-2Sigma1.csv"
    Merge_all = pd.read_csv(path)
    dti = pd.to_datetime(Merge_all['DateTime'], format='%Y-%m-%d %H', exact=False)
    Merge_all.set_index(pd.Index(dti), inplace=True)
    Merge_all.drop(['DateTime'], axis=1, inplace=True)
    First = Merge_all.iloc[0:11000, :]
    N_index = First.shape
    Y_temp = First['FI']
    Y = Y_temp.iloc[hour_ahead:N_index[0]]
    Y = Y.to_numpy()

    X_temp1 = First['FI']
    X_temp2 = First.loc[:, First.columns != 'FI']
    X_temp2_index = X_temp2.index + DateOffset(hours=-hour_ahead)
    X_temp2.set_index(X_temp2_index, inplace=True)
    X_temp1 = X_temp1.to_frame()
    X_temp = X_temp1.join(X_temp2)
    X = X_temp.iloc[0:N_index[0] - hour_ahead]
    X = X.to_numpy()
    Pred_index = X.shape
    print("Shape = "+str(Pred_index))

    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=False)


    from sklearn.linear_model import LinearRegression

    reg = LinearRegression().fit(X_train,y_train)
    predf = reg.predict(X_test)

    MSE = mean_squared_error(y_test, predf, squared=True)
    print("Testing MSE  " + str(MSE))
    RMSE = np.sqrt(MSE)
    print("Testing RMSE  " + str(RMSE))
    MAE = mean_absolute_error(y_test, predf)
    print("Testing MAE  " + str(MAE))
    
    LRhourpreRMSE5.append(RMSE)
    LRhourpreMAE5.append(MAE)

print(LRhourpreRMSE5)
print(LRhourpreMAE5)
# Out:
# Shape = (10999, 780)
# Testing MSE  59.978487174653985
# Testing RMSE  7.7445779210137715
# Testing MAE  5.461440420264715
# Shape = (10998, 780)
# Testing MSE  88.29429465610845
# Testing RMSE  9.396504384935307
# Testing MAE  7.131103857247773
# Shape = (10997, 780)
# Testing MSE  106.88098518799282
# Testing RMSE  10.338326034131097
# Testing MAE  8.226439120042503
# Shape = (10996, 780)
# Testing MSE  117.33334125184362
# Testing RMSE  10.832051571694238
# Testing MAE  8.779527662148753
# Shape = (10995, 780)
# Testing MSE  122.61223542775159
# Testing RMSE  11.073040929561833
# Testing MAE  9.076299513052563
# Shape = (10994, 780)
# Testing MSE  123.80602309523998
# Testing RMSE  11.126815496593801
# Testing MAE  9.140712814742285
# Shape = (10993, 780)
# Testing MSE  123.50501021975985
# Testing RMSE  11.113280803604301
# Testing MAE  9.1018498305382
# Shape = (10992, 780)
# Testing MSE  124.20470698500286
# Testing RMSE  11.144716550231452
# Testing MAE  9.12363558584423
# Shape = (10991, 780)
# Testing MSE  125.94962138576048
# Testing RMSE  11.222727894133426
# Testing MAE  9.19239171398199
# Shape = (10990, 780)
# Testing MSE  130.12224925045703
# Testing RMSE  11.407113975517955
# Testing MAE  9.374098460384083
# Shape = (10989, 780)
# Testing MSE  133.5673101616761
# Testing RMSE  11.557132436797463
# Testing MAE  9.569903283025157
# Shape = (10988, 780)
# Testing MSE  134.67415778287537
# Testing RMSE  11.604919550900616
# Testing MAE  9.645783801237933
# Shape = (10987, 780)
# Testing MSE  134.57248032830404
# Testing RMSE  11.600537932712605
# Testing MAE  9.661502811098797
# Shape = (10986, 780)
# Testing MSE  134.38753995273495
# Testing RMSE  11.592563993902942
# Testing MAE  9.657888256328674
# Shape = (10985, 780)
# Testing MSE  134.01936537585001
# Testing RMSE  11.576673329409015
# Testing MAE  9.64896660214014
# Shape = (10984, 780)
# Testing MSE  134.5224117033215
# Testing RMSE  11.598379701635979
# Testing MAE  9.661254443625346
# Shape = (10983, 780)
# Testing MSE  134.52208374908764
# Testing RMSE  11.598365563694207
# Testing MAE  9.653783614499739
# Shape = (10982, 780)
# Testing MSE  133.55967291534085
# Testing RMSE  11.556802019388446
# Testing MAE  9.614773778961272
# Shape = (10981, 780)
# Testing MSE  129.87883354676026
# Testing RMSE  11.396439511828255
# Testing MAE  9.443400727975181
# Shape = (10980, 780)
# Testing MSE  121.07491584487082
# Testing RMSE  11.003404738755673
# Testing MAE  9.059561954212015
# Shape = (10979, 780)
# Testing MSE  106.15416008543232
# Testing RMSE  10.303114096496861
# Testing MAE  8.444597058250908
# Shape = (10978, 780)
# Testing MSE  88.13961668404448
# Testing RMSE  9.388270164628013
# Testing MAE  7.608277845955504
# Shape = (10977, 780)
# Testing MSE  73.93534668724214
# Testing RMSE  8.59856654839876
# Testing MAE  6.840577220178674
# Shape = (10976, 780)
# Testing MSE  78.77387428433279
# Testing RMSE  8.87546473624524
# Testing MAE  7.0242464786713175
# Shape = (10975, 780)
# Testing MSE  94.85935946487966
# Testing RMSE  9.739576965396376
# Testing MAE  7.826162143902119
# Shape = (10974, 780)
# Testing MSE  110.963596067354
# Testing RMSE  10.5339259569903
# Testing MAE  8.594483867313842
# Shape = (10973, 780)
# Testing MSE  121.34425870477422
# Testing RMSE  11.01563700857895
# Testing MAE  9.090668321098477
# Shape = (10972, 780)
# Testing MSE  127.31909098022298
# Testing RMSE  11.283576160961692
# Testing MAE  9.347438885851913
# Shape = (10971, 780)
# Testing MSE  130.13977446280083
# Testing RMSE  11.407882119955518
# Testing MAE  9.469664595830793
# Shape = (10970, 780)
# Testing MSE  131.51227359406442
# Testing RMSE  11.46788008282544
# Testing MAE  9.526919542064771
# Shape = (10969, 780)
# Testing MSE  130.99260333123266
# Testing RMSE  11.445200012722918
# Testing MAE  9.48196970394235
# Shape = (10968, 780)
# Testing MSE  130.37475802325955
# Testing RMSE  11.41817665055413
# Testing MAE  9.447247743736863
# Shape = (10967, 780)
# Testing MSE  130.60269382209881
# Testing RMSE  11.428153561363219
# Testing MAE  9.44842855454807
# Shape = (10966, 780)
# Testing MSE  131.77708124245373
# Testing RMSE  11.4794199000844
# Testing MAE  9.478375441878073
# Shape = (10965, 780)
# Testing MSE  133.23436545138367
# Testing RMSE  11.542719153275092
# Testing MAE  9.550462344431724
# Shape = (10964, 780)
# Testing MSE  133.6947867168082
# Testing RMSE  11.562646181424398
# Testing MAE  9.588055946790357
# Shape = (10963, 780)
# Testing MSE  133.75817602138295
# Testing RMSE  11.565386981047498
# Testing MAE  9.611119374671574
# Shape = (10962, 780)
# Testing MSE  133.7048761652365
# Testing RMSE  11.56308246814994
# Testing MAE  9.610681819764553
# Shape = (10961, 780)
# Testing MSE  134.21652910572442
# Testing RMSE  11.585185760518664
# Testing MAE  9.639988052646983
# Shape = (10960, 780)
# Testing MSE  134.73886193998896
# Testing RMSE  11.607707006122654
# Testing MAE  9.662253530553155
# Shape = (10959, 780)
# Testing MSE  135.3368702366291
# Testing RMSE  11.633437593275218
# Testing MAE  9.696190645935916
# Shape = (10958, 780)
# Testing MSE  135.20513797286966
# Testing RMSE  11.627774420449928
# Testing MAE  9.68691414257875
# Shape = (10957, 780)
# Testing MSE  132.90258119405092
# Testing RMSE  11.52833818006962
# Testing MAE  9.578970789284433
# Shape = (10956, 780)
# Testing MSE  126.73100004418188
# Testing RMSE  11.257486399911034
# Testing MAE  9.309444176562687
# Shape = (10955, 780)
# Testing MSE  116.4028865540807
# Testing RMSE  10.78901694104151
# Testing MAE  8.859793728398744
# Shape = (10954, 780)
# Testing MSE  103.88589049188586
# Testing RMSE  10.19244281278467
# Testing MAE  8.279563924416081
# Shape = (10953, 780)
# Testing MSE  93.94782308095935
# Testing RMSE  9.692668522185176
# Testing MAE  7.799950289530648
# Shape = (10952, 780)
# Testing MSE  94.63313638481249
# Testing RMSE  9.727956434154734
# Testing MAE  7.821019020029988
# [7.7445779210137715, 9.396504384935307, 10.338326034131097, 10.832051571694238, 11.073040929561833, 11.126815496593801, 11.113280803604301, 11.144716550231452, 11.222727894133426, 11.407113975517955, 11.557132436797463, 11.604919550900616, 11.600537932712605, 11.592563993902942, 11.576673329409015, 11.598379701635979, 11.598365563694207, 11.556802019388446, 11.396439511828255, 11.003404738755673, 10.303114096496861, 9.388270164628013, 8.59856654839876, 8.87546473624524, 9.739576965396376, 10.5339259569903, 11.01563700857895, 11.283576160961692, 11.407882119955518, 11.46788008282544, 11.445200012722918, 11.41817665055413, 11.428153561363219, 11.4794199000844, 11.542719153275092, 11.562646181424398, 11.565386981047498, 11.56308246814994, 11.585185760518664, 11.607707006122654, 11.633437593275218, 11.627774420449928, 11.52833818006962, 11.257486399911034, 10.78901694104151, 10.19244281278467, 9.692668522185176, 9.727956434154734]
# [5.461440420264715, 7.131103857247773, 8.226439120042503, 8.779527662148753, 9.076299513052563, 9.140712814742285, 9.1018498305382, 9.12363558584423, 9.19239171398199, 9.374098460384083, 9.569903283025157, 9.645783801237933, 9.661502811098797, 9.657888256328674, 9.64896660214014, 9.661254443625346, 9.653783614499739, 9.614773778961272, 9.443400727975181, 9.059561954212015, 8.444597058250908, 7.608277845955504, 6.840577220178674, 7.0242464786713175, 7.826162143902119, 8.594483867313842, 9.090668321098477, 9.347438885851913, 9.469664595830793, 9.526919542064771, 9.48196970394235, 9.447247743736863, 9.44842855454807, 9.478375441878073, 9.550462344431724, 9.588055946790357, 9.611119374671574, 9.610681819764553, 9.639988052646983, 9.662253530553155, 9.696190645935916, 9.68691414257875, 9.578970789284433, 9.309444176562687, 8.859793728398744, 8.279563924416081, 7.799950289530648, 7.821019020029988]

# %%
import pandas as pd
import numpy as np
from IPython.display import display
from fastai.imports import *
from sklearn import metrics
from pandas.tseries.offsets import DateOffset
import matplotlib.pyplot as plt

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

Hour_ahead = 48

LRhourpreRMSE6 = []
LRhourpreMAE6 = []
for a in range(Hour_ahead):
    hour_ahead = a+1
    path = "/content/drive/MyDrive/Colab Notebooks/Project/No noise/NoiseMu2Sigma1.csv"
    Merge_all = pd.read_csv(path)
    dti = pd.to_datetime(Merge_all['DateTime'], format='%Y-%m-%d %H', exact=False)
    Merge_all.set_index(pd.Index(dti), inplace=True)
    Merge_all.drop(['DateTime'], axis=1, inplace=True)
    First = Merge_all.iloc[0:11000, :]
    N_index = First.shape
    Y_temp = First['FI']
    Y = Y_temp.iloc[hour_ahead:N_index[0]]
    Y = Y.to_numpy()

    X_temp1 = First['FI']
    X_temp2 = First.loc[:, First.columns != 'FI']
    X_temp2_index = X_temp2.index + DateOffset(hours=-hour_ahead)
    X_temp2.set_index(X_temp2_index, inplace=True)
    X_temp1 = X_temp1.to_frame()
    X_temp = X_temp1.join(X_temp2)
    X = X_temp.iloc[0:N_index[0] - hour_ahead]
    X = X.to_numpy()
    Pred_index = X.shape
    print("Shape = "+str(Pred_index))

    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=False)


    from sklearn.linear_model import LinearRegression

    reg = LinearRegression().fit(X_train,y_train)
    predf = reg.predict(X_test)

    MSE = mean_squared_error(y_test, predf, squared=True)
    print("Testing MSE  " + str(MSE))
    RMSE = np.sqrt(MSE)
    print("Testing RMSE  " + str(RMSE))
    MAE = mean_absolute_error(y_test, predf)
    print("Testing MAE  " + str(MAE))
    
    LRhourpreRMSE6.append(RMSE)
    LRhourpreMAE6.append(MAE)

print(LRhourpreRMSE6)
print(LRhourpreMAE6)
# Out:
# Shape = (10999, 780)
# Testing MSE  60.91080892794649
# Testing RMSE  7.804537713916596
# Testing MAE  5.540405464380703
# Shape = (10998, 780)
# Testing MSE  88.26113614206031
# Testing RMSE  9.394739812366296
# Testing MAE  7.165559961038778
# Shape = (10997, 780)
# Testing MSE  104.88897439622723
# Testing RMSE  10.241531838364182
# Testing MAE  8.176051399624887
# Shape = (10996, 780)
# Testing MSE  114.21288209222796
# Testing RMSE  10.687042719678253
# Testing MAE  8.631189856914997
# Shape = (10995, 780)
# Testing MSE  118.5240404668148
# Testing RMSE  10.88687468775198
# Testing MAE  8.895585742148166
# Shape = (10994, 780)
# Testing MSE  119.61737480003308
# Testing RMSE  10.936972835297393
# Testing MAE  8.94953212546989
# Shape = (10993, 780)
# Testing MSE  119.27782402782151
# Testing RMSE  10.92143873433448
# Testing MAE  8.9065211485367
# Shape = (10992, 780)
# Testing MSE  120.09070602962814
# Testing RMSE  10.95859051290941
# Testing MAE  8.917232371130567
# Shape = (10991, 780)
# Testing MSE  122.19818622984965
# Testing RMSE  11.054328845744081
# Testing MAE  9.003290810492116
# Shape = (10990, 780)
# Testing MSE  126.01524084408389
# Testing RMSE  11.225651020946799
# Testing MAE  9.160940944489107
# Shape = (10989, 780)
# Testing MSE  129.49640709711278
# Testing RMSE  11.379648812556246
# Testing MAE  9.340013224849942
# Shape = (10988, 780)
# Testing MSE  130.27495790151175
# Testing RMSE  11.413805583656652
# Testing MAE  9.396577127547513
# Shape = (10987, 780)
# Testing MSE  130.55909709817556
# Testing RMSE  11.42624597574267
# Testing MAE  9.416713579283961
# Shape = (10986, 780)
# Testing MSE  130.20065584410443
# Testing RMSE  11.410550199009004
# Testing MAE  9.406213752289393
# Shape = (10985, 780)
# Testing MSE  129.85390705943658
# Testing RMSE  11.395345850804029
# Testing MAE  9.407391224385456
# Shape = (10984, 780)
# Testing MSE  129.96000227294385
# Testing RMSE  11.40000009969052
# Testing MAE  9.411034056237082
# Shape = (10983, 780)
# Testing MSE  130.14473899867903
# Testing RMSE  11.408099710235664
# Testing MAE  9.414977149575922
# Shape = (10982, 780)
# Testing MSE  129.17170558519285
# Testing RMSE  11.365373094852313
# Testing MAE  9.370367836316621
# Shape = (10981, 780)
# Testing MSE  125.96210250471671
# Testing RMSE  11.223283944760407
# Testing MAE  9.229232489481872
# Shape = (10980, 780)
# Testing MSE  117.77135174371281
# Testing RMSE  10.852250998927035
# Testing MAE  8.854443102709078
# Shape = (10979, 780)
# Testing MSE  103.48865403757955
# Testing RMSE  10.172937335773751
# Testing MAE  8.21935988273802
# Shape = (10978, 780)
# Testing MSE  85.77876396413969
# Testing RMSE  9.26168256658258
# Testing MAE  7.365344676786952
# Shape = (10977, 780)
# Testing MSE  73.42238981408971
# Testing RMSE  8.568686586291374
# Testing MAE  6.6721309082448625
# Shape = (10976, 780)
# Testing MSE  78.45352440032883
# Testing RMSE  8.857399415196813
# Testing MAE  6.923869084322517
# Shape = (10975, 780)
# Testing MSE  93.5925969127877
# Testing RMSE  9.674326690410433
# Testing MAE  7.716974128306965
# Shape = (10974, 780)
# Testing MSE  108.59967736897941
# Testing RMSE  10.42111689642619
# Testing MAE  8.444498857322971
# Shape = (10973, 780)
# Testing MSE  117.9577402121378
# Testing RMSE  10.86083515260856
# Testing MAE  8.88504233379109
# Shape = (10972, 780)
# Testing MSE  123.4970238267898
# Testing RMSE  11.112921480276453
# Testing MAE  9.127842508440628
# Shape = (10971, 780)
# Testing MSE  125.98469772117954
# Testing RMSE  11.224290521951913
# Testing MAE  9.23520096047211
# Shape = (10970, 780)
# Testing MSE  127.09610947349326
# Testing RMSE  11.273691031489786
# Testing MAE  9.281950000460743
# Shape = (10969, 780)
# Testing MSE  126.92362397407231
# Testing RMSE  11.266038521772963
# Testing MAE  9.26131114764826
# Shape = (10968, 780)
# Testing MSE  126.5231279642976
# Testing RMSE  11.24824999563477
# Testing MAE  9.241068955122199
# Shape = (10967, 780)
# Testing MSE  127.0830628057349
# Testing RMSE  11.273112383265541
# Testing MAE  9.248715174064284
# Shape = (10966, 780)
# Testing MSE  128.30709204575888
# Testing RMSE  11.327272047839182
# Testing MAE  9.300117936053578
# Shape = (10965, 780)
# Testing MSE  129.8127547122006
# Testing RMSE  11.393540043033184
# Testing MAE  9.375489359142538
# Shape = (10964, 780)
# Testing MSE  130.29540032616814
# Testing RMSE  11.41470106162085
# Testing MAE  9.408099053148323
# Shape = (10963, 780)
# Testing MSE  130.58345503873593
# Testing RMSE  11.427311802814165
# Testing MAE  9.434312682475069
# Shape = (10962, 780)
# Testing MSE  130.18349399012334
# Testing RMSE  11.409798157291098
# Testing MAE  9.419890257603257
# Shape = (10961, 780)
# Testing MSE  130.51375700229127
# Testing RMSE  11.42426177056055
# Testing MAE  9.43229225190556
# Shape = (10960, 780)
# Testing MSE  131.05602708411666
# Testing RMSE  11.447970435152104
# Testing MAE  9.452786522341551
# Shape = (10959, 780)
# Testing MSE  131.73663543787964
# Testing RMSE  11.477658099014784
# Testing MAE  9.48353084765836
# Shape = (10958, 780)
# Testing MSE  131.64599461121202
# Testing RMSE  11.473708842881278
# Testing MAE  9.478439802997736
# Shape = (10957, 780)
# Testing MSE  129.41775027895767
# Testing RMSE  11.376192257471638
# Testing MAE  9.383518771064653
# Shape = (10956, 780)
# Testing MSE  123.7340680452292
# Testing RMSE  11.123581619479815
# Testing MAE  9.142884425047605
# Shape = (10955, 780)
# Testing MSE  114.40337664526227
# Testing RMSE  10.695951413748206
# Testing MAE  8.723905366287939
# Shape = (10954, 780)
# Testing MSE  102.05051031117164
# Testing RMSE  10.10200526188596
# Testing MAE  8.137497163818464
# Shape = (10953, 780)
# Testing MSE  92.5915211085236
# Testing RMSE  9.622448810387281
# Testing MAE  7.664244018024913
# Shape = (10952, 780)
# Testing MSE  94.76393888829614
# Testing RMSE  9.734677133233344
# Testing MAE  7.755145687495119
# [7.804537713916596, 9.394739812366296, 10.241531838364182, 10.687042719678253, 10.88687468775198, 10.936972835297393, 10.92143873433448, 10.95859051290941, 11.054328845744081, 11.225651020946799, 11.379648812556246, 11.413805583656652, 11.42624597574267, 11.410550199009004, 11.395345850804029, 11.40000009969052, 11.408099710235664, 11.365373094852313, 11.223283944760407, 10.852250998927035, 10.172937335773751, 9.26168256658258, 8.568686586291374, 8.857399415196813, 9.674326690410433, 10.42111689642619, 10.86083515260856, 11.112921480276453, 11.224290521951913, 11.273691031489786, 11.266038521772963, 11.24824999563477, 11.273112383265541, 11.327272047839182, 11.393540043033184, 11.41470106162085, 11.427311802814165, 11.409798157291098, 11.42426177056055, 11.447970435152104, 11.477658099014784, 11.473708842881278, 11.376192257471638, 11.123581619479815, 10.695951413748206, 10.10200526188596, 9.622448810387281, 9.734677133233344]
# [5.540405464380703, 7.165559961038778, 8.176051399624887, 8.631189856914997, 8.895585742148166, 8.94953212546989, 8.9065211485367, 8.917232371130567, 9.003290810492116, 9.160940944489107, 9.340013224849942, 9.396577127547513, 9.416713579283961, 9.406213752289393, 9.407391224385456, 9.411034056237082, 9.414977149575922, 9.370367836316621, 9.229232489481872, 8.854443102709078, 8.21935988273802, 7.365344676786952, 6.6721309082448625, 6.923869084322517, 7.716974128306965, 8.444498857322971, 8.88504233379109, 9.127842508440628, 9.23520096047211, 9.281950000460743, 9.26131114764826, 9.241068955122199, 9.248715174064284, 9.300117936053578, 9.375489359142538, 9.408099053148323, 9.434312682475069, 9.419890257603257, 9.43229225190556, 9.452786522341551, 9.48353084765836, 9.478439802997736, 9.383518771064653, 9.142884425047605, 8.723905366287939, 8.137497163818464, 7.664244018024913, 7.755145687495119]

# %%
import matplotlib.pyplot as plt
import numpy as np

Hour_ahead = 48

plt.figure(figsize=(10, 6), dpi=80)
plt.plot(np.arange(len(LRhourpreRMSE))+1, LRhourpreRMSE, color="blue", linewidth=2.5, linestyle="-", label='Linear Regression')
plt.plot(np.arange(len(LRhourpreRMSE2))+1, LRhourpreRMSE2, color="red", linewidth=2.5, linestyle="-", label='Linear Regression (with noise, mean is 0, standard deviation is 1)')
plt.plot(np.arange(len(LRhourpreRMSE3))+1, LRhourpreRMSE3, color="purple", linewidth=2.5, linestyle="-", label='Linear Regression (with noise, mean is 0, standard deviation is 0.5)')
plt.plot(np.arange(len(LRhourpreRMSE4))+1, LRhourpreRMSE4, color="green", linewidth=2.5, linestyle="-", label='Linear Regression (with noise, mean is 0, standard deviation is 2)')
plt.plot(np.arange(len(LRhourpreRMSE5))+1, LRhourpreRMSE5, color="yellow", linewidth=2.5, linestyle="-", label='Linear Regression (with noise, mean is -2, standard deviation is 1)')
plt.plot(np.arange(len(LRhourpreRMSE6))+1, LRhourpreRMSE6, color="orange", linewidth=2.5, linestyle="-", label='Linear Regression (with noise, mean is 2, standard deviation is 1)')
plt.xlabel('Hours')
plt.ylabel('RMSE')
plt.grid(linestyle='-')
plt.xlim(0, Hour_ahead+1)  
plt.xticks(np.arange(0, len(LRhourpreRMSE)+1, 2.0))
plt.legend( bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80)
plt.plot(np.arange(len(LRhourpreMAE))+1, LRhourpreMAE, color="blue", linewidth=2.5, linestyle="-", label='Linear Regression')
plt.plot(np.arange(len(LRhourpreMAE2))+1, LRhourpreMAE2, color="red", linewidth=2.5, linestyle="-", label='Linear Regression (with noise, mean is 0, standard deviation is 1)')
plt.plot(np.arange(len(LRhourpreMAE3))+1, LRhourpreMAE3, color="purple", linewidth=2.5, linestyle="-", label='Linear Regression (with noise, mean is 0, standard deviation is 0.5)')
plt.plot(np.arange(len(LRhourpreMAE4))+1, LRhourpreMAE4, color="green", linewidth=2.5, linestyle="-", label='Linear Regression (with noise, mean is 0, standard deviation is 2)')
plt.plot(np.arange(len(LRhourpreMAE5))+1, LRhourpreMAE5, color="yellow", linewidth=2.5, linestyle="-", label='Linear Regression (with noise, mean is -2, standard deviation is 1)')
plt.plot(np.arange(len(LRhourpreMAE6))+1, LRhourpreMAE6, color="orange", linewidth=2.5, linestyle="-", label='Linear Regression (with noise, mean is 2, standard deviation is 1)')
plt.xlabel('Hours')
plt.ylabel('MAE')
plt.grid(linestyle='-')
plt.xlim(0, Hour_ahead+1)  
plt.xticks(np.arange(0, len(LRhourpreRMSE)+1, 2.0))
plt.legend( bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
